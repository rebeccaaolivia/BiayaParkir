# %%
def selamatDatang():
    print("[== SELAMAT DATANG DI PARKIRAN KAMI ==]")
    print(" ")

def terimaKasih():
    print(" ")
    print(" ")
    print("Biaya Parkir anda adalah sebesar = Rp", bParkirkendaraan)
    print("[======= TERIMA KASIH 🙏 =======]")

def StrukPembayaran():
    print("                                                  ")
    print("==================================================")
    print("================ STRUK PEMBAYARAN ================")
    print("==                                              ==")
    print("== NAMA            = ", nama)
    print("==                                                ")
    print("== TIPE KENDARAAN  = ", tipeKendaraan)
    print("==                                                ")
    print("== JENIS KENDARAAN = ", kendaraan)
    print("==                                                ")
    print("== LAMA PARKIR     = ", lamaParkirKendaraan,("jam"))
    print("==                                                ")
    print("== BIAYA PARKIR    =  Rp.",bParkirkendaraan)
    print("==                                                ")
    print("== TANGGAL         = ", tanggal)
    print("==                                              ==")
    print("================ TERIMA KASIH ^_^ ================")
    print("==================================================")

print("[================= MENU KONFIRMASI =================]")
print("[== Apakah anda ingin memulai program parkir ini? ==]")
print("[==== jika iya, input 1 dan jika tidak, input 2 ====]")
konfirmasi = int(input())

while True:
  if konfirmasi == 1:
    print("Silakan Masukan Nama Anda = ")
    nama = input()
    print("Silakan masukan tanggal parkir anda")
    print("contoh 01 januari 2021")
    tanggal = input()
    print(" ")
    print("Hallo ", nama ,("^_^"))
    print(" ")
    selamatDatang()
    listBiaya = [1000,2000,3000,4000,5000]

    print("Silakan TULIS tipe kendaraan anda")
    print("Pilihannya adalah: Kendaraan Pribadi, Angkutan umum dan Angkutan Barang")
    print("TULIS salah satu, contoh = Kendaraan Pribadi")
    tipeKendaraan = input()
    print(" ")
    print("Silakan TULIS Jenis Kendaraan Anda")
    print("Pilihannya adalah: Motor, Mobil, Angkot, Bus, dan Truk")
    print("TULIS salah satu, contoh = Mobil")
    kendaraan = input()
    print(" ")

    print("Jika kendaraan anda adalah Motor input 1")
    print("Jika kendaraan anda adalah Mobil input 2")
    print("Jika kendaraan anda adalah Angkot input 3")
    print("Jika kendaraan anda adalah Bus input 4, dan")
    print("Jika kendaraan anda adalah Truk input 5")
    print("Contoh = 1")
    jenisKendaraan = int(input())
    print(" ")
    if jenisKendaraan == 1:
        print("Kapan Anda memasuki area parkir?")
        print("input waktu dalam jam_(01 sd 24), contoh = 10")
        jamMasuk = int(input())
        print(" ")
        print("Kapan anda keluar dari area parkir?")
        print("input waktu dalam jam_(01 sd 24), contoh = 12")
        jamKeluar = int(input())
        lamaParkirKendaraan = jamKeluar - jamMasuk
        bParkirkendaraan = lamaParkirKendaraan * listBiaya[0]
        terimaKasih()
        StrukPembayaran()
    else:
        if jenisKendaraan == 2:
            print("Kapan Anda memasuki area parkir?")
            print("input waktu dalam jam_(01 sd 24), contoh = 10")
            jamMasuk = int(input())
            print(" ")
            print("Kapan anda keluar dari area parkir?")
            print("input waktu dalam jam_(01 sd 24), contoh = 12")
            jamKeluar = int(input())
            lamaParkirKendaraan = jamKeluar - jamMasuk
            bParkirkendaraan = lamaParkirKendaraan * listBiaya[2]
            terimaKasih()
            StrukPembayaran()
        else:
            if jenisKendaraan == 3:
                print("Kapan Anda memasuki area parkir?")
                print("input waktu dalam jam_(01 sd 24), contoh = 10")
                jamMasuk = int(input())
                print(" ")
                print("Kapan anda keluar dari area parkir?")
                print("input waktu dalam jam_(01 sd 24), contoh = 12")
                jamKeluar = int(input())
                lamaParkirKendaraan = jamKeluar - jamMasuk
                bParkirkendaraan = lamaParkirKendaraan * listBiaya[1]
                terimaKasih()
                StrukPembayaran()
            else:
                if jenisKendaraan == 4:
                    print("Kapan Anda memasuki area parkir?")
                    print("input waktu dalam jam_(01 sd 24), contoh = 10")
                    jamMasuk = int(input())
                    print(" ")
                    print("Kapan anda keluar dari area parkir?")
                    print("input waktu dalam jam_(01 sd 24), contoh = 12")
                    jamKeluar = int(input())
                    lamaParkirKendaraan = jamKeluar - jamMasuk
                    bParkirkendaraan = lamaParkirKendaraan * listBiaya[3]
                    terimaKasih()
                    StrukPembayaran()
                else:
                    if jenisKendaraan == 5:
                        print("Kapan Anda memasuki area parkir?")
                        print("input waktu dalam jam_(01 sd 24), contoh = 10")
                        jamMasuk = int(input())
                        print(" ")
                        print("Kapan anda keluar dari area parkir?")
                        print("input waktu dalam jam_(01 sd 24), contoh = 12")
                        jamKeluar = int(input())
                        lamaParkirKendaraan = jamKeluar - jamMasuk
                        bParkirkendaraan = lamaParkirKendaraan * listBiaya[4]
                        terimaKasih()
                        StrukPembayaran()
                    else:
                        print("Maaf, input yang anda masukan mungkin salah")
                        print("jenis kendaraan harus di isi dengan input 1,2,3,4 atau 5")
                        print("silakan ulangi pengisian data anda")
                        print("TERIMA KASIH ^_^")

  else:
      if konfirmasi == 2:
         print(" === TERIMA KASIH ^_^ === ")
         break

      else:
         print("= Maaf, mungkin anda memasukan input yang salah =")
         print("Silakan isi MENU KONFIRMASI dengan input 1 atau 2")
         print("============== TERIMA KASIH ^_^ =================")
         break
# Out:
# [================= MENU KONFIRMASI =================]
# [== Apakah anda ingin memulai program parkir ini? ==]
# [==== jika iya, input 1 dan jika tidak, input 2 ====]
# Silakan Masukan Nama Anda =
# Silakan masukan tanggal parkir anda
# contoh 01 januari 2021
#
# Hallo  Yoga Andriyanto ^_^
#
# [== SELAMAT DATANG DI PARKIRAN KAMI ==]
#
# Silakan TULIS tipe kendaraan anda
# Pilihannya adalah: Kendaraan Pribadi, Angkutan umum dan Angkutan Barang
# TULIS salah satu, contoh = Kendaraan Pribadi
#
# Silakan TULIS Jenis Kendaraan Anda
# Pilihannya adalah: Motor, Mobil, Angkot, Bus, dan Truk
# TULIS salah satu, contoh = Mobil
#
# Jika kendaraan anda adalah Motor input 1
# Jika kendaraan anda adalah Mobil input 2
# Jika kendaraan anda adalah Angkot input 3
# Jika kendaraan anda adalah Bus input 4, dan
# Jika kendaraan anda adalah Truk input 5
# Contoh = 1
#
# Kapan Anda memasuki area parkir?
# input waktu dalam jam_(01 sd 24), contoh = 10
#
# Kapan anda keluar dari area parkir?
# ...
